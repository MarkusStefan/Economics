# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkusStefan/Economics/blob/main/Int_Macro_Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0.02
R = 200000
cost = 50000000
FV = 0
year = 1
while FV < cost:
  FV += R/(1+i)**year
  year += 1
'''  print(FV)
print(year)'''

# %%
i = 0.02
R = 200000
cost = 50000000
FV = 0
for i in range(10000):
  FV = FV + R/(1+i)**i
FV
# Out:
# 325694.7425803168

# %%
i = 0.02
R = 200000
cost = 50000000
FV = 0
for n in range(1,11):
  rent = R/(1+i)**n
  #print(FV, '\t', rent)
  FV += rent
print(f'')
# Out:
# 1796517.0012484472

# %%
i = 0.02
R = 200000
cost = 50000000
FV = 0
n = 1 # years
while FV < 50_000_000:
  if n <= 50:
    rent = R/(1+i)**n
    FV += rent
    if n % 10 == 0:
      print(f'Future Value at year %i:\t%f\t discounted return: %f' %(n,FV,rent))
    n += 1
  else:
    break
# Out:
# Future Value at year 10:	1796517.001248	 discounted return: 164069.659975
# Future Value at year 20:	3270286.668919	 discounted return: 134594.266622
# Future Value at year 30:	4479291.110201	 discounted return: 110414.177796
# Future Value at year 40:	5471095.848148	 discounted return: 90578.083037
# Future Value at year 50:	6284721.178730	 discounted return: 74305.576425

# %%
i = 0.02
R = 500_000
cost = 100_000_000
FV = 0
n = 1 # years
while FV < cost:
  if n <= 1000:
    rent = R/(1+i)**n
    FV += rent
    if n == 10 or n == 100 or n == 1000:
      print(f'Future Value at year %i:\t%f\t discounted return: %f' %(n,FV,rent))
    n += 1
  else:
    break
#    rent = R/(1+i)**n
#    FV += rent
#    n += 1
#print(f'Future Value at year %i:\t%f\t discounted return: %f' %(n,FV,rent))
# Out:
# Future Value at year 10:	4491292.503121	 discounted return: 410174.149938
# Future Value at year 100:	21549175.820056	 discounted return: 69016.483599
# Future Value at year 1000:	24999999.937228	 discounted return: 0.001255

# %%
310/0.4
410/0.4
370/0.4
410/4000
100+0.4*(925-100)
150+0.2*925-4000*0.01
430+295+180
350/0.4
100+0.4*925-40+150+0.2*925+180
-20/-4000
# Out:
# 0.005

# %% [markdown]
# ## IS-LM curve

# %% [markdown]
# Calculate the equilibrium value of Y

# %%
from sympy import symbols, Eq, solve
Y = symbols('Y');# r = symbols('r');

T_ = 100
T_e = 100
Y_e = 925
r = 0.01
r_e = 0.01

# Y = C + I + G_
C = (105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e)
I = (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e)
G_ = 200

IS = C + I + G_
"""
IS = ((105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e) + 
     (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e) +
     G_
)
"""

eq = Eq((Y),IS)
print(solve((eq), Y))
# Out:
# [925.000000000000]

# %% [markdown]
# What is the impact of decreasing government spending to G' = 180 in terms of the new equilibrium value Y'?

# %%
from sympy import symbols, Eq, solve
Y = symbols('Y');

T_ = 100
T_e = 100
Y_e = 925
r = 0.01
r_e = 0.01

# Y = C + I + G_
C = (105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e)
I = (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e)
G_ = 200 - 20

IS = C + I + G_
"""
IS = ((105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e) + 
     (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e) +
     G_
)
"""

eq = Eq((Y),IS)
print(solve((eq), Y))
# Out:
# [896.428571428571]

# %% [markdown]
# A credible fiscal consolidation program changes expectations for taxes to T'e = 80. Calculate the new equilibrium value Y''. Show the shift in the IS curve using a sketch (no need for exact graph). G_ = 100!!!

# %%
from sympy import symbols, Eq, solve
Y = symbols('Y')

T_ = 100
T_e = 100 - 20 ####
Y_e = 925
r = 0.01
r_e = 0.01

# Y = C + I + G_
C = (105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e)
I = (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e)
G_ = 200

IS = C + I + G_
"""
IS = ((105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e) + 
     (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e) +
     G_
)
"""

eq = Eq((Y),IS)
print(solve((eq), Y))
# Out:
# [925.000000000000]

# %% [markdown]
# A credible fiscal consolidation program changes expectations for taxes to T'e = 80. Calculate the new equilibrium value Y''. Show the shift in the IS curve using a sketch (no need for exact graph).

# %%
from sympy import symbols, Eq, solve
r = symbols('r')

Y = 925
T_ = 100
T_e = 100 - 20 ####
Y_e = 925
#r = 0.01
r_e = 0.01

# Y = C + I + G_
C = (105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e)
I = (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e)
G_ = 200 - 20 ####

IS = C + I + G_
"""
IS = ((105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e) + 
     (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e) +
     G_
)
"""

eq = Eq((r),IS)
print(solve((eq), r))
# Out:
# [0.464267866066967]

# %%
from sympy import symbols, Eq, solve
r_e = symbols('r_e')

Y = 925
T_ = 100
T_e = 100 - 20 ####
Y_e = 925
r = 0.01
#r_e = 0.01

# Y = C + I + G_
C = (105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e)
I = (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e)
G_ = 200 - 20 ####

IS = C + I + G_
"""
IS = ((105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e) + 
     (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e) +
     G_
)
"""

eq = Eq((r_e),IS)
print(solve((eq), r_e))
# Out:
# [0.373450619752099]

# %% [markdown]
# Suppose that the economic agents expect a reduction in the expected real interest rate due to the fiscal stabilization. Which new r’e is required in order to keep equilibrium output at the value obtained for Y in (a) (G’ = 180, T’e = 80)? Show the shift in the IS curve using a sketch.

# %%
from sympy import symbols, Eq, solve
Y = symbols('Y')

T_ = 100
T_e = 100 - 20 ####
Y_e = 925
r = 0.01
r_e = 0.01

# Y = C + I + G_
C = (105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e)
I = (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e)
G_ = 200 - 20 ####

IS = C + I + G_
"""
IS = ((105 + 0.2*(Y-T_) + 0.2*(Y_e-T_e) - 500 * r_e) + 
     (150 + 0.1*Y - 2_000*r + 0.1*Y_e - 2_000*r_e) +
     G_
)
"""

eq = Eq((Y),IS)
print(solve((eq), Y))

# %%
# importing library sympy
from sympy import symbols, Eq, solve

# defining symbols used in equations
# or unknown variables
m = 200
x, y, z = symbols('x,y,z')

# defining equations
eq1 = Eq((x+y+z), 1)
print("Equation 1:")
print(eq1)

eq2 = Eq((x-y+2*z), 1)
print("Equation 2")
print(eq2)

eq3 = Eq((2*x-y+2*z), 1)
print("Equation 3")


# solving the equation and printing the
# value of unknown variables
print("Values of 3 unknown variable are as follows:")
print(solve((eq1, eq2, eq3), (x, y, z)))
# Out:
# Equation 1:
# Eq(x + y + z, 1)
# Equation 2
# Eq(x - y + 2*z, 1)
# Equation 3
# Values of 3 unknown variable are as follows:
# {x: 0, y: 1/3, z: 2/3}

# %%
# %load_ext rpy2.ipython
# %reload_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# x = 10:100
# x

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


countries = ["AT", "DE"]
pop = [9*10**6, 78*10**6]

df = pd.DataFrame({
    "countries" : countries,
    "population" : pop,
    "public debt % of GDP" : [99.91, 63.90],
    "unemployment rate %" : [6.3, 3.54]
    })

plt.bar(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4f9745269339> in <module>
#      14     })
#      15
# ---> 16 plt.bar(df, height="population")
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
# ...

# %%
econ = pd.read_csv("https://raw.githubusercontent.com/MarkusStefan/Data_Analytics/main/export.csv", sep=";")
#econ.astype(float)
#econ=econ.astype(str)
econ.iloc(1)

# %%
def string_to_int(df):
  try:
    for col in df.columns:
      for val in  df[col]:
        val = val.replace(',', '')
        val = val.replace(',', '')
  except ValueError:
    print('wrong values entered')
  
  return df
  
string_to_int(econ)


#string = "2219.212,0012"
#string.replace('.', "")
#string.replace(',', "")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-dec52399fa93> in <module>
#      10   return df
#      11
# ---> 12 string_to_int(econ)
#      13
#      14
#
# <ipython-input-57-dec52399fa93> in string_to_int(df)
#       3     for col in df.columns:
#       4       for val in  df[col]:
# ----> 5         val = val.replace(',', '')
#       6         val = val.replace(',', '')
#       7   except ValueError:
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
plt.plot(econ.Year, econ["GDPpCAT"])
plt.plot(econ.Year, econ["GDPpCDE"])
plt.legend(['Austria GDP per capita', 'Germany GDP per capita'])
#plt.plot(df.Date, mean, color='r')
#plt.plot(df.Date, sd1, linestyle='dashed', ntry)

# %%
import pandas as pd
import requests
url = "https://www.imf.org/external/datamapper/api/v1/NGDP_RPCH/AUT/DEU?year=2023&yaxis=lin"
response = requests.get(url)
data = response.json()

df = pd.read_json(url)
#pd.DataFrame(df['values'])
data
# Out:
# {'values': {'NGDP_RPCH': {'AUT': {'1980': 2.3,
#     '1981': -0.1,
#     '1982': 1.9,
#     '1983': 2.8,
#     '1984': 0.3,
#     '1985': 2.2,
#     '1986': 2.3,
#     '1987': 1.7,
#     '1988': 1,
#     '1989': 3.9,
#     '1990': 4.3,
#     '1991': 3.4,
#     '1992': 2.1,
#     '1993': 0.5,
#     '1994': 2.4,
#     '1995': 2.7,
#     '1996': 2.4,
#     '1997': 2.1,
#     '1998': 3.6,
#     '1999': 3.6,
#     '2000': 3.4,
#     '2001': 1.3,
#     '2002': 1.7,
#     '2003': 0.9,
#     '2004': 2.7,
#     '2005': 2.2,
#     '2006': 3.5,
#     '2007': 3.7,
#     '2008': 1.5,
#     '2009': -3.8,
#     '2010': 1.8,
#     '2011': 2.9,
#     '2012': 0.7,
#     '2013': 0,
#     '2014': 0.7,
#     '2015': 1,
#     '2016': 2,
#     '2017': 2.3,
#     '2018': 2.5,
#     '2019': 1.5,
#     '2020': -6.7,
#     '2021': 4.6,
#     '2022': 4.7,
#     '2023': 1,
#     '2024': 1.9,
#     '2025': 1.8,
#     '2026': 1.7,
#     '2027': 1.7},
#    'DEU': {'1980': 1.3,
#     '1981': 0.1,
# ...

# %%
# selecting the first cell which includes the json data
nGDP = pd.DataFrame(df.iloc[0,0])
# converting index to datetime for plotting
nGDP.index = pd.to_datetime(nGDP.index)

import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(nGDP.index, nGDP['AUT'])
plt.plot(nGDP.index, nGDP['DEU'])
plt.legend(['Austria real GDP growth %', 'Germany real GDP growth'])

# %%
import pandas as pd
import requests
url = "https://www.imf.org/external/datamapper/api/v1/LUR/AUT/DEU?year=2023&yaxis=lin"
response = requests.get(url)
data = response.json()

df = pd.read_json(url)

# selecting the first cell which includes the json data
ue = pd.DataFrame(df.iloc[0,0])
# converting index to datetime for plotting
ue.index = pd.to_datetime(ue.index)

import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(ue.index, ue['AUT'])
plt.plot(ue.index, ue['DEU'])
plt.legend(['Austria Unemployment rate % ', 'Germany Unemployment rate %'])
